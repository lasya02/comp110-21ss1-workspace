# %% [markdown]
# # Hypothesis: There are more students enrolled in schools in countries that spend more on education.

# %% [markdown]
# First, let's import pandas so that we can get started and then access our data set.

# %%
import pandas as pd
worldbank = pd.read_csv("../../data/databank_education_2018.csv")

# %% [markdown]
# Let's find the shape of our data - the number of rows and the number of columns that we have

# %%
worldbank.shape
# Out:
# (244, 94)

# %% [markdown]
# To get a look at our data, let's print out the first 10 lines

# %%
worldbank.head(10)
# Out:
#                Country  SE.COM.DURS  SE.ENR.PRIM.FM.ZS  SE.ENR.PRSC.FM.ZS  \
# 0          Afghanistan          9.0            0.66691            0.63602
# 1              Albania          9.0            1.03765            1.01730
# 2              Algeria         10.0            0.95499                NaN
# 3              Andorra         10.0                NaN                NaN
# 4               Angola          6.0                NaN                NaN
# 5  Antigua and Barbuda         11.0            0.99208            0.97924
# 6           Arab World          9.0            0.94617            0.94833
# 7            Argentina         14.0                NaN                NaN
# 8              Armenia         12.0            0.99961            1.02283
# 9                Aruba         13.0                NaN                NaN
#
#    SE.ENR.SECO.FM.ZS  SE.ENR.TERT.FM.ZS  SE.PRE.DURS  SE.PRE.ENRL.TC.ZS  \
# 0            0.57098            0.34523          1.0                NaN
# ...

# %%
spending = SE.XPD.TOTL.GD.ZS 
enrollment = SE.TER.ENRR 
specific = worldbank[["Country", spending, enrollment]]

# %%
specific.head(10)
specific.shape
# Out:
# (244, 3)

# %%
complete = specific[(specific["SE.XPD.TOTL.GD.ZS"].notna()) & (specific["SE.TER.ENRR"].notna())]

# %%
complete.head(10)
# Out:
#                    Country  SE.XPD.TOTL.GD.ZS  SE.TER.ENRR
# 12              Azerbaijan            2.45543    27.708500
# 19                  Belize            7.56149    24.540840
# 20                   Benin            2.93397    12.516990
# 22                  Bhutan            6.85084    15.554510
# 27  British Virgin Islands            2.46599    16.254089
# 30            Burkina Faso            5.38379     6.501870
# 31                 Burundi            5.07865     4.057660
# 33                Cambodia            2.16286    13.687760
# 34                Cameroon            3.13120    14.267270
# 42                Colombia            4.45749    55.327492

# %%
complete.shape
# Out:
# (46, 3)

# %%
sorted = complete.sort_values("SE.XPD.TOTL.GD.ZS", 0, False)

# %%
sorted.head(10)
# Out:
#           Country  SE.XPD.TOTL.GD.ZS  SE.TER.ENRR
# 19         Belize            7.56149    24.540840
# 126       Lesotho            6.98519    10.196260
# 46     Costa Rica            6.97857    55.207939
# 22         Bhutan            6.85084    15.554510
# 200  South Africa            6.15899    23.801960
# 91       Honduras            6.06746    26.164221
# 154    Mozambique            5.49985     7.312550
# 149       Moldova            5.43973    39.821239
# 30   Burkina Faso            5.38379     6.501870
# 221          Togo            5.36957    14.523930

# %%
y = sorted.plot.scatter(x = "SE.XPD.TOTL.GD.ZS", y = "SE.TER.ENRR", title = "Correlation between spening on expenditure and school enrollment for 46 countries")

y.set_ylabel("School enrollment, tertiary (% gross)")

y.set_xlabel("Government expenditure on education (% of GDP)")
# Out:
# Text(0.5, 0, 'Government expenditure on education (% of GDP)')

# %%
sorted["SE.TER.ENRR"].corr(sorted["SE.XPD.TOTL.GD.ZS"])
# Out:
# -0.10779558762554745
